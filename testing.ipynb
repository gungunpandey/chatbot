# %%
import pdfplumber
import pandas as pd
from llama_index.core import VectorStoreIndex, Document
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Load PDF and extract text and tables
pdf_path = "7df4dbdc-eb62-4d53-bc27-d334bfcb2335.pdf"
text = ""
tables = []

with pdfplumber.open(pdf_path) as pdf:
    for page in pdf.pages:
        text += page.extract_text()
        page_tables = page.extract_tables()
        for table in page_tables:
            df = pd.DataFrame(table[1:], columns=table[0])
            tables.append(df)

# Inspect DataFrames
for i, df in enumerate(tables):
    print(f"DataFrame {i} columns:\n{df.columns}\n")
    print(f"DataFrame {i} head:\n{df.head()}\n")

# Handle duplicate columns
for i, df in enumerate(tables):
    if df.columns.duplicated().any():
        print(f"DataFrame {i} has duplicate columns: {df.columns[df.columns.duplicated()].unique()}")
        # Rename duplicate columns
        df.columns = [f"{col}_{j}" if duplicated else col
                      for j, (col, duplicated) in enumerate(zip(df.columns, df.columns.duplicated()))]
        tables[i] = df

# Align columns
all_columns = set()
for df in tables:
    all_columns.update(df.columns)

for i, df in enumerate(tables):
    tables[i] = df.reindex(columns=all_columns)

# Remove duplicates if necessary
tables = [df.drop_duplicates() for df in tables]

# Concatenate DataFrames
try:
    combined_table = pd.concat(tables, ignore_index=True)
    print(combined_table.head())
except Exception as e:
    print(f"Error during concatenation: {e}")

# Split text into chunks
max_chunk_size = 2000  # Smaller chunks for batch processing
chunks = [text[i:i + max_chunk_size] for i in range(0, len(text), max_chunk_size)]

# Load quantized model and tokenizer
model_name = "facebook/bart-base"  # Smaller model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Summarization function
def summarize_text(text):
    inputs = tokenizer(text, return_tensors="pt", max_length=512, truncation=True)
    summary_ids = model.generate(inputs['input_ids'], max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# Summarize each chunk
batch_size = 4
summaries = []
for i in range(0, len(chunks), batch_size):
    batch_chunks = chunks[i:i + batch_size]
    batch_summaries = [summarize_text(chunk) for chunk in batch_chunks]
    summaries.extend(batch_summaries)

# Combine summaries
final_summary = " ".join(summaries)
print(final_summary)

# Convert tables to string format
def tables_to_string(tables):
    table_strings = []
    for table in tables:
        table_strings.append(table.to_string(index=False))
    return "\n\n".join(table_strings)

# Convert combined table to string
table_string = tables_to_string(tables)

# Create documents from text chunks and table string
documents = [Document(text=chunk) for chunk in chunks] + [Document(text=table_string)]

# Initialize VectorStoreIndex
index = VectorStoreIndex.from_documents(documents)

# Function to perform QnA
def ask_question(question):
    response = index.query(question)
    return response

# Example question
question = "What is the net income for NVIDIA for the three months ended October 29, 2023?"
answer = ask_question(question)
print(answer)
# Out:
# DataFrame 0 columns:
# Index(['Revenue', '$', '18,120', '', '$', '5,931', '', '$', '38,819', '', '$',
#        '20,923'],
#       dtype='object')
#
# DataFrame 0 head:
#                              Revenue       $ 18,120        $ 5,931         $  \
# 0                    Cost of revenue   4,720   None    2,754  None    11,309
# 1                       Gross profit  13,400   None    3,177  None    27,510
# 2                 Operating expenses           None           None
# 3           Research and development   2,294   None    1,945  None     6,210
# 4  Sales, general and administrative     689   None      631  None     1,942
#
#   38,819         $ 20,923
# 0   None     9,400   None
# 1   None    11,523   None
# 2   None             None
# 3   None     5,387   None
# 4   None     1,815   None
#
# DataFrame 1 columns:
# Index(['Net income', '$', '9,243', '', '$', '680', '', '$', '17,475', '', '$',
#        '2,954'],
#       dtype='object')
#
# DataFrame 1 head:
#                                           Net income  $ 9,243       $   680    \
# 0               Other comprehensive loss, net of tax     None          None
# 1                     Available-for-sale securities:     None          None
# 2               Net change in unrealized gain (loss)  —  None    (18)  None
# 3  Reclassification adjustments for net realized ...  —  None       —  None
# 4               Net change in unrealized gain (loss)  —  None    (18)  None
#
#    $ 17,475       $ 2,954
# 0      None          None
# 1      None          None
# 2  7   None    (53)  None
# 3  —   None       1  None
# 4  7   None    (52)  None
#
# DataFrame 2 columns:
# Index(['ASSETS', '', None, '', '', None], dtype='object')
#
# DataFrame 2 head:
#                       ASSETS           None            None
# 0            Current assets:           None            None
# 1  Cash and cash equivalents       $  5,519        $  3,389
# 2      Marketable securities  12,762   None    9,907   None
# 3   Accounts receivable, net   8,309   None    3,827   None
# 4                Inventories   4,779   None    5,159   None
#
# DataFrame 3 columns:
# Index(['Balances, July 30, 2023', '2,469', '', '$', '2', '', '$', '12,629', '',
#        '$', '(51)', '', '$', '14,921', '', '$', '27,501'],
#       dtype='object')
#
# DataFrame 3 head:
#                              Balances, July 30, 2023 2,469    $     2    \
# 0                                         Net income     —    —  None
# 1                           Other comprehensive loss     —    —  None
# 2          Issuance of common stock from stock plans     7    —  None
# 3  Tax withholding related to vesting of restrict...   (2)    —  None
# 4                                 Shares repurchased   (8)    —  None
#
#        $ 12,629       $  (51)          $ 14,921          $ 27,501
# 0      —   None       —  None      9,243   None      9,243   None
# 1      —   None    (37)  None          —   None       (37)   None
# 2    157   None       —  None          —   None        157   None
# 3  (764)   None       —  None          —   None      (764)   None
# 4   (14)   None       —  None    (3,705)   None    (3,719)   None
#
# DataFrame 4 columns:
# Index(['Balances, January 29, 2023', '2,466', '', '$', '2', '', '$', '11,971',
#        '', '$', '(43)', '', '$', '10,171', '', '$', '22,101'],
#       dtype='object')
#
# DataFrame 4 head:
#                           Balances, January 29, 2023 2,466    $     2    \
# 0                                         Net income     —    —  None
# 1                           Other comprehensive loss     —    —  None
# 2          Issuance of common stock from stock plans    21    —  None
# 3  Tax withholding related to vesting of restrict...   (5)    —  None
# 4                                 Shares repurchased  (16)    —  None
#
#          $ 11,971       $  (43)          $ 10,171          $ 22,101
# 0        —   None       —  None     17,475   None     17,475   None
# 1        —   None    (45)  None          —   None       (45)   None
# 2      403   None       —  None          —   None        403   None
# 3  (1,942)   None       —  None          —   None    (1,942)   None
# 4     (15)   None       —  None    (6,990)   None    (7,005)   None
#
# DataFrame 5 columns:
# Index(['Cash flows from operating activities:', '', None, '', '', None], dtype='object')
#
# DataFrame 5 head:
#                Cash flows from operating activities:           None           \
# 0                                         Net income      $  17,475        $
# 1  Adjustments to reconcile net income to net cas...           None
# 2                   Stock-based compensation expense  2,555    None    1,971
# 3                      Depreciation and amortization  1,121    None    1,118
# 4            Losses on investments in non-affiliates     24    None       35
#
#     None
# 0  2,954
# 1   None
# 2   None
# 3   None
# 4   None
#
# DataFrame 6 columns:
# Index(['Fiscal Year:', '', None], dtype='object')
#
# DataFrame 6 head:
#                                         Fiscal Year:       None
# 0  2024 (excluding first nine months of fiscal ye...    $    84
# 1                                               2025  269  None
# 2                                               2026  248  None
# 3                                               2027  233  None
# 4                                               2028  220  None
#
# DataFrame 7 columns:
# Index(['Supplemental cash flows information', '', None, '', '', None], dtype='object')
#
# DataFrame 7 head:
#                  Supplemental cash flows information    None      None
# 0     Operating cash flows used for operating leases  $  200    $  134
# 1  Operating lease assets obtained in exchange fo...  $  439    $  213
#
# DataFrame 8 columns:
# Index([           None, '(In millions)',            None,            None,
#                   None,            None,            None,            None,
#                   None,            None,            None,            None],
#       dtype='object')
#
# DataFrame 8 head:
#                                 None (In millions)  None None None  None None  \
# 0                    Cost of revenue             $    38         $    32
# 1           Research and development           701  None       530  None
# 2  Sales, general and administrative           240  None       183  None
# 3                              Total             $   979         $   745
#
#     None   None None   None   None
# 0      $     96           $    108
# 1  1,826   None       1,365   None
# 2    633   None         498   None
# 3      $  2,555           $  1,971
#
# DataFrame 9 columns:
# Index(['Balances, January 29, 2023', '45', '', '$', '158.45'], dtype='object')
#
# DataFrame 9 head:
#    Balances, January 29, 2023    45    $  158.45
# 0                     Granted    13    $  364.52
# 1                      Vested  (16)    $  141.02
# 2      Canceled and forfeited   (1)    $  201.49
# 3  Balances, October 29, 2023    41    $  230.11
#
# DataFrame 10 columns:
# Index(['Numerator:', '', None, '', '', None, '', '', None, '', None], dtype='object')
#
# DataFrame 10 head:
#                                      Numerator:          None           None  \
# 0                                    Net income      $  9,243        $   680
# 1                                  Denominator:          None           None
# 2                 Basic weighted average shares  2,468   None    2,483  None
# 3  Dilutive impact of outstanding equity awards     26   None       16  None
# 4               Diluted weighted average shares  2,494   None    2,499  None
#
#               None          None
# 0        $  17,475      $  2,954
# 1             None          None
# 2    2,470    None  2,495   None
# 3       24    None     22   None
# 4    2,494    None  2,517   None
#
# DataFrame 11 columns:
# Index(['Corporate debt securities', '$', '6,937', '$', '1', '', '$', '(20)',
#        '', '$', '6,918', '', '$', '1,714', '$', '5,204'],
#       dtype='object')
#
# DataFrame 11 head:
#                            Corporate debt securities      $ 6,937  $     1    \
# 0       Debt securities issued by the U.S.\nTreasury  5,075  None  1  None
# 1                                 Money market funds  3,190  None  —  None
# 2  Debt securities issued by U.S.\ngovernment age...  2,316  None  —  None
# 3                            Certificates of deposit    418  None  —  None
# 4                           Foreign government bonds    175  None  —  None
#
#       $  (20)        $ 6,918        $ 1,714      $ 5,204
# 0  (24)  None    5,052  None        —  None  5,052  None
# 1     —  None    3,190  None    3,190  None      —  None
# 2   (5)  None    2,311  None      100  None  2,211  None
# 3     —  None      418  None      198  None    220  None
# 4     —  None      175  None      100  None     75  None
#
# DataFrame 12 columns:
# Index(['Corporate debt securities', '$', '4,809', '$', '—', '', '$', '(12)',
#        '', '$', '4,797', '', '$', '1,087', '$', '3,710'],
#       dtype='object')
#
# DataFrame 12 head:
#                            Corporate debt securities      $ 4,809  $     —    \
# 0       Debt securities issued by the U.S.\nTreasury  4,185  None  1  None
# 1  Debt securities issued by U.S.\ngovernment age...  1,836  None  —  None
# 2                                 Money market funds  1,777  None  —  None
# 3                            Certificates of deposit    365  None  —  None
# 4                           Foreign government bonds    140  None  —  None
#
#       $  (12)        $ 4,797        $ 1,087      $ 3,710
# 0  (44)  None    4,142  None        —  None  4,142  None
# 1   (2)  None    1,834  None       50  None  1,784  None
# 2     —  None    1,777  None    1,777  None      —  None
# 3     —  None      365  None      134  None    231  None
# 4     —  None      140  None      100  None     40  None
#
# DataFrame 13 columns:
# Index(['Corporate debt securities', '$', '2,773', '$', '(16)', '$', '852', '$',
#        '(4)', '$', '3,625', '$', '(20)'],
#       dtype='object')
#
# DataFrame 13 head:
#                            Corporate debt securities      $  2,773     $  \
# 0       Debt securities issued by the U.S.\nTreasury  2,098   None  (12)
# 1  Debt securities issued by U.S.\ngovernment age...  1,447   None   (5)
# 2                                              Total      $  6,318     $
#
#    (16)      $    852     $   (4)      $  3,625     $  (20)
# 0  None  1,371   None  (12)  None  3,469   None  (24)  None
# 1  None      —   None     —  None  1,447   None   (5)  None
# 2  (33)      $  2,223     $  (16)      $  8,541     $  (49)
#
# DataFrame 14 columns:
# Index(['Debt securities issued by the U.S.\nTreasury', '$', '2,444', '$',
#        '(21)', '$', '1,172', '$', '(23)', '$', '3,616', '$', '(44)'],
#       dtype='object')
#
# DataFrame 14 head:
#         Debt securities issued by the U.S.\nTreasury      $  2,444    $  (21)  \
# 0                          Corporate debt securities  1,188   None  (7)  None
# 1  Debt securities issued by U.S.\ngovernment age...  1,307   None  (2)  None
# 2                                              Total      $  4,939    $  (30)
#
#      $  1,172    $  (23)      $  3,616     $  (44)
# 0  696   None  (5)  None  1,884   None  (12)  None
# 1    —   None    —  None  1,307   None   (2)  None
# 2    $  1,868    $  (28)      $  6,807     $  (58)
#
# DataFrame 15 columns:
# Index(['Less than one year', '$', '11,405', '', '$', '11,388', '', '$',
#        '9,738', '$', '9,708'],
#       dtype='object')
#
# DataFrame 15 head:
#    Less than one year      $  11,405        $  11,388        $   9,738  $  \
# 0  Due in 1 - 5 years  6,706    None    6,676    None    3,374    None
# 1               Total      $  18,111        $  18,064        $  13,112  $
#
#     9,708
# 0   3,347
# 1  13,055
#
# DataFrame 16 columns:
# Index(['Assets', '', '', '', None, '', '', None], dtype='object')
#
# DataFrame 16 head:
#                                               Assets                 None    \
# 0        Cash equivalents and marketable securities:                 None
# 1                                 Money market funds  Level 1    $  3,190
# 2                          Corporate debt securities  Level 2    $  6,918
# 3        Debt securities issued by the U.S. Treasury  Level 2    $  5,052
# 4  Debt securities issued by U.S. government agen...  Level 2    $  2,311
#
#        None
# 0      None
# 1  $  1,777
# 2  $  4,797
# 3  $  4,142
# 4  $  1,834
#
# DataFrame 17 columns:
# Index(['Acquisition-related\nintangible assets', '$', '2,642', '', '$',
#        '(1,584)', '', '$', '1,058', '', '$', '3,093', '', '$', '(1,614)', '$',
#        '1,479'],
#       dtype='object')
#
# DataFrame 17 head:
#   Acquisition-related\nintangible assets    $  2,642        $  (1,584)      $  \
# 0       Patents and licensed\ntechnology  450   None    (257)     None    193
# 1                Total intangible assets    $  3,092        $  (1,841)      $
#
#    1,058      $  3,093        $  (1,614)    $  1,479
# 0   None    446   None    (249)     None  197   None
# 1  1,251      $  3,539        $  (1,863)    $  1,676
#
# DataFrame 18 columns:
# Index(['Fiscal Year:', '', None], dtype='object')
#
# DataFrame 18 head:
#                                         Fiscal Year:       None
# 0  2024 (excluding first nine months of fiscal ye...    $   143
# 1                                               2025  554  None
# 2                                               2026  259  None
# 3                                               2027  149  None
# 4                                               2028   37  None
#
# DataFrame 19 columns:
# Index(['Raw materials', '$', '1,663', '$', '2,430'], dtype='object')
#
# DataFrame 19 head:
#        Raw materials      $  1,663      $  2,430
# 0    Work in-process  1,338   None    466   None
# 1     Finished goods  1,778   None  2,263   None
# 2  Total inventories      $  4,779      $  5,159
#
# DataFrame 20 columns:
# Index(['Prepaid supply and capacity agreements (1)', '$', '2,927', '', '$',
#        '2,989'],
#       dtype='object')
#
# DataFrame 20 head:
#   Prepaid supply and capacity agreements (1)      $  2,927      $  2,989
# 0     Investments in non-affiliated entities  1,172   None    299   None
# 1                          Prepaid royalties    369   None    387   None
# 2                     Prepaid cloud services     60   None     23   None
# 3                                      Other    139   None    122   None
# 4                         Total other assets      $  4,667      $  3,820
#
# DataFrame 21 columns:
# Index(['Customer program accruals', '$', '1,771', '', '$', '1,196'], dtype='object')
#
# DataFrame 21 head:
#                    Customer program accruals      $ 1,771      $ 1,196
# 0  Excess inventory purchase obligations (1)  1,280  None    954  None
# 1       Accrued payroll and related expenses    516  None    530  None
# 2                       Deferred revenue (2)    513  None    354  None
# 3                              Taxes payable    420  None    467  None
# 4     Product warranty and return provisions    299  None    108  None
#
# DataFrame 22 columns:
# Index(['Income tax payable (1)', '$', '1,206', '', '$', '1,204'], dtype='object')
#
# DataFrame 22 head:
#               Income tax payable (1)    $  1,206      $  1,204
# 0               Deferred revenue (2)  425   None    218   None
# 1                Deferred income tax  424   None    247   None
# 2                   Licenses payable  113   None    181   None
# 3                              Other   66   None     63   None
# 4  Total other long-term liabilities    $  2,234      $  1,913
#
# DataFrame 23 columns:
# Index(['Balance at beginning of period', '$', '572', '', '$', '502'], dtype='object')
#
# DataFrame 23 head:
#                  Balance at beginning of period      $   572        $   502
# 0  Deferred revenue additions during the period  1,269  None      577  None
# 1          Revenue recognized during the period  (903)  None    (528)  None
# 2                      Balance at end of period      $   938        $   551
#
# DataFrame 24 columns:
# Index(['Designated as cash flow hedges', '$', '1,148', '', '$', '1,128'], dtype='object')
#
# DataFrame 24 head:
#   Designated as cash flow hedges  $ 1,148    $ 1,128
# 0          Non-designated hedges  $   365    $   366
#
# DataFrame 25 columns:
# Index(['0.309% Notes Due 2023', '', '—', '', '0.41%', '', '$', '—', '', '$',
#        '1,250'],
#       dtype='object')
#
# DataFrame 25 head:
#    0.309% Notes Due 2023      —    0.41%        $     —        $ 1,250
# 0  0.584% Notes Due 2024    0.6    0.66%    1,250  None    1,250  None
# 1   3.20% Notes Due 2026    2.9    3.31%    1,000  None    1,000  None
# 2   1.55% Notes Due 2028    4.6    1.64%    1,250  None    1,250  None
# 3   2.85% Notes Due 2030    6.4    2.93%    1,500  None    1,500  None
# 4   2.00% Notes Due 2031    7.6    2.09%    1,250  None    1,250  None
#
# DataFrame 26 columns:
# Index(['Fiscal Year:', '', None], dtype='object')
#
# DataFrame 26 head:
#                                         Fiscal Year:           None
# 0  2024 (excluding first nine months of fiscal ye...       $  6,499
# 1                                               2025  11,861   None
# 2                                               2026   1,128   None
# 3                                               2027   1,038   None
# 4                                               2028     660   None
#
# DataFrame 27 columns:
# Index(['Three Months Ended', '', 'Nine Months Ended', None], dtype='object')
#
# DataFrame 27 head:
#   Three Months Ended   Nine Months Ended None
# 0               None    October 29, 2023
#
# DataFrame 28 columns:
# Index(['Balance at beginning of period', '$', '115', '', '$', '168', '', '$',
#        '82', '', '$', '46'],
#       dtype='object')
#
# DataFrame 28 head:
#   Balance at beginning of period     $   115       $   168       $    82    \
# 0                      Additions    50  None       3  None     105  None
# 1                    Utilization  (23)  None    (67)  None    (45)  None
# 2       Balance at end of period     $   142       $   104       $   142
#
#       $    46
# 0   141  None
# 1  (83)  None
# 2     $   104
#
# DataFrame 29 columns:
# Index(['Three Months Ended October 29, 2023',
#                                           '',
#                                         None,
#                                           '',
#                                           '',
#                                         None,
#                                           '',
#                                           '',
#                                         None,
#                                           '',
#                                           '',
#                                         None],
#       dtype='object')
#
# DataFrame 29 head:
#    Three Months Ended October 29, 2023       None        None          None    \
# 0                              Revenue  $  14,645    $  3,475    $        —
# 1              Operating income (loss)  $  10,262    $  1,493    $  (1,338)
# 2                                            None        None          None
# 3  Three Months Ended October 30, 2022       None        None          None
# 4                              Revenue  $   3,816    $  2,115    $        —
#
#         None
# 0  $  18,120
# 1  $  10,417
# 2       None
# 3       None
# 4  $   5,931
#
# DataFrame 30 columns:
# Index(['Stock-based compensation expense', '$', '(979)', '', '$', '(745)', '',
#        '$', '(2,555)', '', '$', '(1,971)'],
#       dtype='object')
#
# DataFrame 30 head:
#                     Stock-based compensation expense      $ (979)        $  \
# 0  Unallocated cost of revenue and operating expe...  (198)  None    (156)
# 1                Acquisition-related and other costs  (135)  None    (174)
# 2                                   IP-related costs   (26)  None        —
# 3                       Acquisition termination cost      —  None        —
# 4                                              Other      —  None     (16)
#
#   (745)        $ (2,555)          $ (1,971)
# 0  None    (515)    None      (432)    None
# 1  None    (446)    None      (499)    None
# 2  None     (36)    None          —    None
# 3  None        —    None    (1,353)    None
# 4  None       10    None       (25)    None
#
# DataFrame 31 columns:
# Index(['United States', '$', '6,302', '', '$', '2,148', '', '$', '14,730', '',
#        '$', '6,069'],
#       dtype='object')
#
# DataFrame 31 head:
#                  United States      $   6,302        $  2,148        $  \
# 0                       Taiwan  4,333    None    1,153   None    8,968
# 1  China (including Hong Kong)  4,030    None    1,148   None    8,360
# 2                    Singapore  2,702    None      536   None    4,506
# 3              Other countries    753    None      946   None    2,255
# 4                Total revenue      $  18,120        $  5,931        $
#
#    14,730        $   6,069
# 0    None    5,134    None
# 1    None    4,831    None
# 2    None    1,963    None
# 3    None    2,926    None
# 4  38,819        $  20,923
#
# DataFrame 32 columns:
# Index(['Data Center', '$', '14,514', '', '$', '3,833', '', '$', '29,121', '',
#        '$', '11,389'],
#       dtype='object')
#
# DataFrame 32 head:
#                   Data Center      $  14,514        $  3,833        $  29,121  \
# 0                      Gaming  2,856    None    1,574   None    7,582    None
# 1  Professional Visualization    416    None      200   None    1,090    None
# 2                  Automotive    261    None      251   None      810    None
# 3               OEM and Other     73    None       73   None      216    None
# 4               Total revenue      $  18,120        $  5,931        $  38,819
#
#          $  11,389
# 0    7,236    None
# 1    1,318    None
# 2      609    None
# 3      371    None
# 4        $  20,923
#
# DataFrame 33 columns:
# Index(['Revenue', '$', '18,120', '', '', '$', '13,507', '', '', '$', '5,931',
#        '', '', '34', '%', '', '206', '%'],
#       dtype='object')
#
# DataFrame 33 head:
#                         Revenue     $  18,120          $ 13,507          $  \
# 0                  Gross margin  74.0    None  %    70.1   None  %    53.6
# 1            Operating expenses     $   2,983          $  2,662          $
# 2              Operating income     $  10,417          $  6,800          $
# 3                    Net income     $   9,243          $  6,188          $
# 4  Net income per diluted share     $    3.71          $   2.48          $
#
#    5,931            34     %         206     %
# 0   None  %    3.9 pts  None    20.4 pts  None
# 1  2,576            12     %          16     %
# 2    601            53     %       1,633     %
# 3    680            49     %       1,259     %
# 4   0.27            50     %       1,274     %
#
# DataFrame 34 columns:
# Index(['Revenue', '100.0', '%', '', '100.0', '%', '', '100.0', '%', '',
#        '100.0', '%'],
#       dtype='object')
#
# DataFrame 34 head:
#                              Revenue 100.0     %   100.0     %   100.0     %  \
# 0                    Cost of revenue  26.0          46.4          29.1
# 1                       Gross profit  74.0          53.6          70.9
# 2                 Operating expenses        None          None          None
# 3           Research and development  12.7          32.8          16.0
# 4  Sales, general and administrative   3.8          10.6           5.0
#
#     100.0     %
# 0    44.9
# 1    55.1
# 2          None
# 3    25.7
# 4     8.7
#
# DataFrame 35 columns:
# Index(['Compute & Networking', '$', '14,645', '', '$', '3,816', '', '$',
#        '10,829', '', '284', '%', '', '$', '29,507', '', '$', '11,395', '', '$',
#        '18,112', '', '159', '%'],
#       dtype='object')
#
# DataFrame 35 head:
#   Compute & Networking      $  14,645        $  3,816        $  10,829    ...  \
# 0             Graphics  3,475    None    2,115   None    1,360    None    ...
# 1                Total      $  18,120        $  5,931        $  12,189    ...
#
#    29,507        $  11,395        $  18,112    159  %
# 0    None    9,528    None    (216)    None    (2)  %
# 1  38,819        $  20,923        $  17,896     86  %
#
# [2 rows x 24 columns]
#
# DataFrame 36 columns:
# Index(['Research and\ndevelopment\nexpenses', '$', '2,294', '', '$', '1,945',
#        '', '$', '349', '18', '%', '', '$', '6,210', '', '$', '5,387', '', '$',
#        '823', '15', '%'],
#       dtype='object')
#
# DataFrame 36 head:
#             Research and\ndevelopment\nexpenses     $ 2,294        $ 1,945     \
# 0                              % of net revenue  12.7  None  %  32.8  None  %
# 1  Sales, general and\nadministrative\nexpenses   689  None      631  None
# 2                              % of net revenue   3.8  None  %  10.6  None  %
# 3                 Acquisition\ntermination cost     —  None        —  None
# 4                              % of net revenue     —  None  %     —  None  %
#
#     $   349 18  ...      $ 6,210         $ 5,387           $   823     15  \
# 0      None     ...   16.0  None  %   25.7  None  %           None
# 1  58  None  9  ...  1,942  None     1,815  None         127  None      7
# 2      None     ...    5.0  None  %    8.7  None  %           None
# 3   —  None  —  ...      —  None     1,353  None     (1,353)  None  (100)
# 4      None     ...      —  None  %    6.5  None  %           None
#
#       %
# 0  None
# 1     %
# 2  None
# 3     %
# 4  None
#
# [5 rows x 22 columns]
#
# DataFrame 37 columns:
# Index(['Compute & Networking', '$', '10,262', '', '$', '1,086', '', '$',
#        '9,176', '845', '%', '', '$', '19,149', '', '$', '3,509', '', '$',
#        '15,640', '446', '%'],
#       dtype='object')
#
# DataFrame 37 head:
#   Compute & Networking        $  10,262          $ 1,086        $  9,176  \
# 0             Graphics    1,493    None        606  None      887   None
# 1            All Other  (1,338)    None    (1,091)  None    (247)   None
# 2                Total        $  10,417          $   601        $  9,816
#
#      845  ...        $  19,149          $  3,509      $  15,640   446  %
# 0    146  ...    3,751    None      3,739   None     12    None     —  %
# 1     23  ...  (3,542)    None    (4,280)   None    738    None  (17)  %
# 2  1,633  ...        $  19,358          $  2,968      $  16,390   552  %
#
# [3 rows x 22 columns]
#
# DataFrame 38 columns:
# Index(['Interest income', '$', '234', '', '$', '88', '', '$', '146', '', '$',
#        '572', '', '$', '152', '$', '420'],
#       dtype='object')
#
# DataFrame 38 head:
#                Interest income     $   234       $    88       $   146    \
# 0             Interest expense  (63)  None    (65)  None       2  None
# 1                   Other, net  (66)  None    (11)  None    (55)  None
# 2  Other income (expense), net     $   105       $    12       $    93
#
#        $   572        $   152  $  420
# 0  (194)  None    (198)  None       4
# 1   (24)  None     (29)  None       5
# 2      $   354        $  (75)  $  429
#
# DataFrame 39 columns:
# Index(['Cash and cash equivalents', '$', '5,519', '$', '3,389'], dtype='object')
#
# DataFrame 39 head:
#                           Cash and cash equivalents       $   5,519      $  \
# 0                             Marketable securities  12,762    None  9,907
# 1  Cash, cash equivalents and marketable securities       $  18,281      $
#
#     3,389
# 0    None
# 1  13,296
#
# DataFrame 40 columns:
# Index(['Net cash provided by operating activities', '$', '16,591', '$',
#        '3,393'],
#       dtype='object')
#
# DataFrame 40 head:
#            Net cash provided by operating activities  $    16,591  $    3,393
# 0  Net cash provided by (used in) investing activ...  $   (4,457)  $    7,378
# 1              Net cash used in financing activities  $  (10,004)  $  (9,961)
#
# DataFrame 41 columns:
# Index(['Due in one year', '', '$', '1,250'], dtype='object')
#
# DataFrame 41 head:
#                                 Due in one year        $ 1,250
# 0                      Due in one to five years    2,250  None
# 1                      Due in five to ten years    2,750  None
# 2                 Due in greater than ten years    3,500  None
# 3  Unamortized debt discount and issuance costs     (44)  None
# 4                           Net carrying amount    9,706  None
#
# DataFrame 42 columns:
# Index(['July 31, 2023 - August 27, 2023', '', '2.2', '', '$', '444.16', '',
#        '2.2', '', '$', '27.95'],
#       dtype='object')
#
# DataFrame 42 head:
#          July 31, 2023 - August 27, 2023    2.2    $  444.16    2.2    $  \
# 0   August 28, 2023 - September 24, 2023    2.6    $  456.81    2.6    $
# 1  September 25, 2023 - October 29, 2023    3.5    $  436.44    3.5    $
# 2                                  Total    8.3         None    8.3
#
#    27.95
# 0  26.78
# 1  25.24
# 2   None
#
# DataFrame 0 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 1 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 2 has duplicate columns: Index(['', None], dtype='object')
# DataFrame 3 has duplicate columns: Index(['', '$'], dtype='object')
# DataFrame 4 has duplicate columns: Index(['', '$'], dtype='object')
# DataFrame 5 has duplicate columns: Index(['', None], dtype='object')
# DataFrame 7 has duplicate columns: Index(['', None], dtype='object')
# DataFrame 8 has duplicate columns: Index([None], dtype='object')
# DataFrame 10 has duplicate columns: Index(['', None], dtype='object')
# DataFrame 11 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 12 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 13 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 14 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 15 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 16 has duplicate columns: Index(['', None], dtype='object')
# DataFrame 17 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 19 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 20 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 21 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 22 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 23 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 24 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 25 has duplicate columns: Index(['', '—', '$'], dtype='object')
# DataFrame 28 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 29 has duplicate columns: Index(['', None], dtype='object')
# DataFrame 30 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 31 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 32 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 33 has duplicate columns: Index(['', '$', '%'], dtype='object')
# DataFrame 34 has duplicate columns: Index(['100.0', '%', ''], dtype='object')
# DataFrame 35 has duplicate columns: Index(['$', '', '%'], dtype='object')
# DataFrame 36 has duplicate columns: Index(['$', '', '%'], dtype='object')
# DataFrame 37 has duplicate columns: Index(['$', '', '%'], dtype='object')
# DataFrame 38 has duplicate columns: Index(['$', ''], dtype='object')
# DataFrame 39 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 40 has duplicate columns: Index(['$'], dtype='object')
# DataFrame 42 has duplicate columns: Index(['', '2.2', '$'], dtype='object')
#     11,971 10,829 Cash flows from operating activities:    %  \
# 0      NaN    NaN                                   NaN  NaN
# 1      NaN    NaN                                   NaN  NaN
# 2      NaN    NaN                                   NaN  NaN
# 3      NaN    NaN                                   NaN  NaN
# 4      NaN    NaN                                   NaN  NaN
#
#   Three Months Ended October 29, 2023 18,112 1,206 15,640 12,629  ...  \
# 0                                 NaN    NaN   NaN    NaN    NaN  ...
# 1                                 NaN    NaN   NaN    NaN    NaN  ...
# 2                                 NaN    NaN   NaN    NaN    NaN  ...
# 3                                 NaN    NaN   NaN    NaN    NaN  ...
# 4                                 NaN    NaN   NaN    NaN    NaN  ...
#
#                              Revenue  234 Supplemental cash flows information  \
# 0                    Cost of revenue  NaN                                 NaN
# 1                       Gross profit  NaN                                 NaN
# 2                 Operating expenses  NaN                                 NaN
# 3           Research and development  NaN                                 NaN
# 4  Sales, general and administrative  NaN                                 NaN
#
#     _7 3,093     $_7    $_4  $_5 Debt securities issued by the U.S.\nTreasury  \
# 0  NaN   NaN  11,309  2,754  NaN                                          NaN
# 1  NaN   NaN  27,510  3,177  NaN                                          NaN
# 2  NaN   NaN                 NaN                                          NaN
# 3  NaN   NaN   6,210  1,945  NaN                                          NaN
# 4  NaN   NaN   1,942    631  NaN                                          NaN
#
#   4,809
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 215 columns]
# UNITED STATESCLASSIFIEDSECURITIES AND EXCHANGE COMMISSION UNCLASSIFIEDWashington, D.C. 20549CLASSIFIEDFORM 10-Q UNCLASSIFIED☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGES ACT OF 1934CLASSIFIEDFor the quarterly period ended October 29, 2023CLASSIFIEDORCLASSIFIED☐ TRANSITION REPORT PURSEANT TO PAGE 13 OR 10(d)(1)(a)(a) of the Securities Exchange Act of 1934 UNCLASSIFIEDCommission file number: 0-23985 UNCLASSIFIED(Exact name of registrant as specified in its charter) UNCLASSIFIEDDelaware 94-3177549 UNCLASSIFIED(State or other jurisdiction of (I.R.S. Employ  company” in accordance with “Rule 12b-2 of the Exchange Act.” ☐Large accelerated filer ☒ Accelerated filer☐ Non-accelerated Filer ☐ Smaller reporting company ☐ Emerging growth company ☒ Emerging growth companies ☐========================If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or re-revised financial accounting standards provided pursuant to Section 13(a) of the exchange Act. ☐ =============================================================Item 1. Company’s Financial Condition and Results of Operations 36392Item 2. Financial Accounting Standards 35392Item 3. Legal Proceedings 35392Indicate ote that we announce material financial information to our investors using our investor relations website, press releases,releases, SEC filings and public conference calls and webcasts. We also use the following social media channels as a means of disclosing material information andinformation about the company, our products, our planned financial and other announcements and attendance at upcoming investor and industry events, conferences,conferences, and other matters, and for complying with our disclosure obligations under Regulation FD:======NVIDIA Company Blog (http://blogs.nvidia.com)======NVIDIA LinkedIn Page (https://www.linkedin.com/company/nvidia)============NVIDIA Twitter Account (www.twitter.com/_NVIDIA LinkedIn)============ NVIDIA Facebook Page (www@facebook.  income 10,417 601 19,358 2,968 suburInterest income 234 88 572 152 (61) suburInterest expense (63) (65) (194) (198) suburOther, net (66) (11) (24) (29) (28) subur other income (expense), net 105 12 354 (75) PalestinIncome before income tax 10,522 613 19,712 2,893 suburIncome tax expense (benefit) 1,279 (67) 2,237 (81) suburNet income $ 9,243 $ 680 $ 17,475 $ 2,954 PalestinNet income per share: PalestinBasic $ 3.75 $ 0.27 $ 7.07 $ 1. ngible assets, net 1,251 1,676 suburDeferred income tax assets 5,982 3,396 suburOther assets 4,667 3,820 suburTotal assets $ 54,148 $ 41,182 suburLIABILITIES AND SHAREHOLDERS’ EQUITY======Current liabilities: suburAccounts payable $ 2,380 $ 1,193 suburAccrued and other current liabilities 5,472 4,120 suburShort-term debt 1,249 1,250 suburTotal current liabilities 9,101 6,563 suburLong-term operating lease liabilities 1,091 902 suburOther long-term liabilities 2,234 1,913 suburTotal liabilities 20,883 19,081 suburCommit Listing of restricted stock units (2) — (294) — — (295) —294)▬Shares repurchased (28) — – (1) — 3,646) (3,647)▬Cash dividends declared and paid ($0.04 per common share) — � — — —— (100) (100’s)▬Stock-based compensation — — 749 — — 149 — 1 49▬Balances, October 30, 2022 2,468 $ 2 $ 11,565 $ (123) $ 9,905 $ 21,349▬See accompanying Notes to Condensed Consolidated Financial Statements.(In millions, except per share data) Shares Amount Capital Comprehensive Loss Earnings Equity 22 carbohydCash flows from operating activities:sbmNet income $ 17,475 $ 2,954ahimeAdjustments to reconcile net income to net cash provided by operating activities (17,475) (2,954)ahimeStock-based compensation expense 2,555 1,971ahimeDepreciation and amortization 1,121 1,118ahimeLosses on investments in non-affiliates 24 35ahimeDeferred income taxes (2.411) (1,517) suburAcquisition termination cost — 1,353ahimeOther (170) (27) suburChanges in operating assets and liabilitie ...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 93
#      90 documents = [Document(text=chunk) for chunk in chunks] + [Document(text=table_string)]
#      92 # Initialize VectorStoreIndex
# ---> 93 index = VectorStoreIndex.from_documents(documents)
#      95 # Function to perform QnA
#      96 def ask_question(question):
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/base.py:145, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, service_context, **kwargs)
#     136     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     138 nodes = run_transformations(
#     139     documents,  # type: ignore
#     140     transformations,
#     141     show_progress=show_progress,
#     142     **kwargs,
#     143 )
# --> 145 return cls(
#     146     nodes=nodes,
#     147     storage_context=storage_context,
#     148     callback_manager=callback_manager,
#     149     show_progress=show_progress,
#     150     transformations=transformations,
#     151     service_context=service_context,
#     152     **kwargs,
#     153 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:75, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, service_context, **kwargs)
#      68 self._embed_model = (
#      69     resolve_embed_model(embed_model, callback_manager=callback_manager)
#      70     if embed_model
#      71     else embed_model_from_settings_or_context(Settings, service_context)
#      72 )
#      74 self._insert_batch_size = insert_batch_size
# ---> 75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#      78     service_context=service_context,
#      79     storage_context=storage_context,
#      80     show_progress=show_progress,
#      81     objects=objects,
#      82     callback_manager=callback_manager,
#      83     transformations=transformations,
#      84     **kwargs,
#      85 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/base.py:94, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, service_context, **kwargs)
#      92 if index_struct is None:
#      93     nodes = nodes or []
# ---> 94     index_struct = self.build_index_from_nodes(
#      95         nodes + objects, **kwargs  # type: ignore
#      96     )
#      97 self._index_struct = index_struct
#      98 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:308, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     300 if any(
#     301     node.get_content(metadata_mode=MetadataMode.EMBED) == "" for node in nodes
#     302 ):
#     303     raise ValueError(
#     304         "Cannot build index from nodes with no content. "
#     305         "Please ensure all nodes have content."
#     306     )
# --> 308 return self._build_index_from_nodes(nodes, **insert_kwargs)
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:280, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     278     run_async_tasks(tasks)
#     279 else:
# --> 280     self._add_nodes_to_index(
#     281         index_struct,
#     282         nodes,
#     283         show_progress=self._show_progress,
#     284         **insert_kwargs,
#     285     )
#     286 return index_struct
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:233, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     230     return
#     232 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 233     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     234     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     236     if not self._vector_store.stores_text or self._store_nodes_override:
#     237         # NOTE: if the vector store doesn't store text,
#     238         # we need to add the nodes to the index struct and document store
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:141, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     130 def _get_node_with_embedding(
#     131     self,
#     132     nodes: Sequence[BaseNode],
#     133     show_progress: bool = False,
#     134 ) -> List[BaseNode]:
#     135     """Get tuples of id, node, and embedding.
#     136
#     137     Allows us to store these nodes in a vector store.
#     138     Embeddings are called in batches.
#     139
#     140     """
# --> 141     id_to_embed_map = embed_nodes(
#     142         nodes, self._embed_model, show_progress=show_progress
#     143     )
#     145     results = []
#     146     for node in nodes:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/utils.py:138, in embed_nodes(nodes, embed_model, show_progress)
#     135     else:
#     136         id_to_embed_map[node.node_id] = node.embedding
# --> 138 new_embeddings = embed_model.get_text_embedding_batch(
#     139     texts_to_embed, show_progress=show_progress
#     140 )
#     142 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     143     id_to_embed_map[new_id] = text_embedding
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/base/embeddings/base.py:332, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     323 dispatcher.event(
#     324     EmbeddingStartEvent(
#     325         model_dict=model_dict,
#     326     )
#     327 )
#     328 with self.callback_manager.event(
#     329     CBEventType.EMBEDDING,
#     330     payload={EventPayload.SERIALIZED: self.to_dict()},
#     331 ) as event:
# --> 332     embeddings = self._get_text_embeddings(cur_batch)
#     333     result_embeddings.extend(embeddings)
#     334     event.on_end(
#     335         payload={
#     336             EventPayload.CHUNKS: cur_batch,
#     337             EventPayload.EMBEDDINGS: embeddings,
#     338         },
#     339     )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/embeddings/openai/base.py:432, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     425 """Get text embeddings.
#     426
#     427 By default, this is a wrapper around _get_text_embedding.
#     428 Can be overridden for batch queries.
#     429
#     430 """
#     431 client = self._get_client()
# --> 432 return get_embeddings(
#     433     client,
#     434     texts,
#     435     engine=self._text_engine,
#     436     **self.additional_kwargs,
#     437 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/embeddings/openai/base.py:180, in get_embeddings(client, list_of_text, engine, **kwargs)
#     176 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     178 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 180 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     181 return [d.embedding for d in data]
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
#     [... skipping similar frames: SyncAPIClient._request at line 1031 (7 times), SyncAPIClient._retry_request at line 1079 (7 times)]
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
import pdfplumber
import pandas as pd
from llama_index.core import VectorStoreIndex, Document
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
import torch
from multiprocessing import Pool, cpu_count

# Helper function to process a single PDF page
def process_pdf_page(args):
    pdf_path, page_number = args
    with pdfplumber.open(pdf_path) as pdf:
        page = pdf.pages[page_number]
        text = page.extract_text()
        tables = page.extract_tables()
    return text, tables

# Load PDF and extract text and tables using multiprocessing
pdf_path = "7df4dbdc-eb62-4d53-bc27-d334bfcb2335.pdf"
text = ""
tables = []

with pdfplumber.open(pdf_path) as pdf:
    page_numbers = list(range(len(pdf.pages)))
    with Pool(cpu_count()) as p:
        results = p.map(process_pdf_page, [(pdf_path, page_number) for page_number in page_numbers])

for page_text, page_tables in results:
    text += page_text
    for table in page_tables:
        df = pd.DataFrame(table[1:], columns=table[0])
        tables.append(df)

# Handle duplicate columns and align DataFrames
all_columns = set()
for i, df in enumerate(tables):
    if df.columns.duplicated().any():
        df.columns = [f"{col}_{j}" if duplicated else col
                      for j, (col, duplicated) in enumerate(zip(df.columns, df.columns.duplicated()))]
    all_columns.update(df.columns)

for i, df in enumerate(tables):
    tables[i] = df.reindex(columns=all_columns).drop_duplicates()

# Concatenate DataFrames
try:
    combined_table = pd.concat(tables, ignore_index=True)
    print(combined_table.head())
except Exception as e:
    print(f"Error during concatenation: {e}")

# Split text into chunks
max_chunk_size = 2000
chunks = [text[i:i + max_chunk_size] for i in range(0, len(text), max_chunk_size)]

# Load model and tokenizer with GPU support
model_name = "facebook/bart-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")

# Summarization function with GPU support
def summarize_text(text):
    inputs = tokenizer(text, return_tensors="pt", max_length=512, truncation=True)
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    summary_ids = model.generate(inputs['input_ids'], max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    return summary

# Summarize each chunk in batches
batch_size = 4
summaries = []
for i in range(0, len(chunks), batch_size):
    batch_chunks = chunks[i:i + batch_size]
    batch_summaries = [summarize_text(chunk) for chunk in batch_chunks]
    summaries.extend(batch_summaries)

# Combine summaries
final_summary = " ".join(summaries)
print(final_summary)

# Convert tables to string format
def tables_to_string(tables):
    table_strings = []
    for table in tables:
        table_strings.append(table.to_string(index=False))
    return "\n\n".join(table_strings)

# Convert combined table to string
table_string = tables_to_string(tables)

# Create documents from text chunks and table string
documents = [Document(text=chunk) for chunk in chunks] + [Document(text=table_string)]

# Initialize VectorStoreIndex
index = VectorStoreIndex.from_documents(documents)

# Function to perform QnA
def ask_question(question):
    response = index.query(question)
    return response

# Example question
question = "What is the net income for NVIDIA for the three months ended October 29, 2023?"
answer = ask_question(question)
print(answer)
# Out:
#     11,971 10,829 Cash flows from operating activities:    %  \
# 0      NaN    NaN                                   NaN  NaN
# 1      NaN    NaN                                   NaN  NaN
# 2      NaN    NaN                                   NaN  NaN
# 3      NaN    NaN                                   NaN  NaN
# 4      NaN    NaN                                   NaN  NaN
#
#   Three Months Ended October 29, 2023 18,112 1,206 15,640 12,629  ...  \
# 0                                 NaN    NaN   NaN    NaN    NaN  ...
# 1                                 NaN    NaN   NaN    NaN    NaN  ...
# 2                                 NaN    NaN   NaN    NaN    NaN  ...
# 3                                 NaN    NaN   NaN    NaN    NaN  ...
# 4                                 NaN    NaN   NaN    NaN    NaN  ...
#
#                              Revenue  234 Supplemental cash flows information  \
# 0                    Cost of revenue  NaN                                 NaN
# 1                       Gross profit  NaN                                 NaN
# 2                 Operating expenses  NaN                                 NaN
# 3           Research and development  NaN                                 NaN
# 4  Sales, general and administrative  NaN                                 NaN
#
#     _7 3,093     $_7    $_4  $_5 Debt securities issued by the U.S.\nTreasury  \
# 0  NaN   NaN  11,309  2,754  NaN                                          NaN
# 1  NaN   NaN  27,510  3,177  NaN                                          NaN
# 2  NaN   NaN                 NaN                                          NaN
# 3  NaN   NaN   6,210  1,945  NaN                                          NaN
# 4  NaN   NaN   1,942    631  NaN                                          NaN
#
#   4,809
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 215 columns]
# UNITED STATESCLASSIFIEDSECURITIES AND EXCHANGE COMMISSION UNCLASSIFIEDWashington, D.C. 20549CLASSIFIEDFORM 10-Q UNCLASSIFIED☒ QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGES ACT OF 1934CLASSIFIEDFor the quarterly period ended October 29, 2023CLASSIFIEDORCLASSIFIED☐ TRANSITION REPORT PURSEANT TO PAGE 13 OR 10(d)(1)(a)(a) of the Securities Exchange Act of 1934 UNCLASSIFIEDCommission file number: 0-23985 UNCLASSIFIED(Exact name of registrant as specified in its charter) UNCLASSIFIEDDelaware 94-3177549 UNCLASSIFIED(State or other jurisdiction of (I.R.S. Employ  company” in accordance with “Rule 12b-2 of the Exchange Act.” ☐Large accelerated filer ☒ Accelerated filer☐ Non-accelerated Filer ☐ Smaller reporting company ☐ Emerging growth company ☒ Emerging growth companies ☐========================If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or re-revised financial accounting standards provided pursuant to Section 13(a) of the exchange Act. ☐ =============================================================Item 1. Company’s Financial Condition and Results of Operations 36392Item 2. Financial Accounting Standards 35392Item 3. Legal Proceedings 35392Indicate ote that we announce material financial information to our investors using our investor relations website, press releases,releases, SEC filings and public conference calls and webcasts. We also use the following social media channels as a means of disclosing material information andinformation about the company, our products, our planned financial and other announcements and attendance at upcoming investor and industry events, conferences,conferences, and other matters, and for complying with our disclosure obligations under Regulation FD:======NVIDIA Company Blog (http://blogs.nvidia.com)======NVIDIA LinkedIn Page (https://www.linkedin.com/company/nvidia)============NVIDIA Twitter Account (www.twitter.com/_NVIDIA LinkedIn)============ NVIDIA Facebook Page (www@facebook.  income 10,417 601 19,358 2,968 suburInterest income 234 88 572 152 (61) suburInterest expense (63) (65) (194) (198) suburOther, net (66) (11) (24) (29) (28) subur other income (expense), net 105 12 354 (75) PalestinIncome before income tax 10,522 613 19,712 2,893 suburIncome tax expense (benefit) 1,279 (67) 2,237 (81) suburNet income $ 9,243 $ 680 $ 17,475 $ 2,954 PalestinNet income per share: PalestinBasic $ 3.75 $ 0.27 $ 7.07 $ 1. ngible assets, net 1,251 1,676 suburDeferred income tax assets 5,982 3,396 suburOther assets 4,667 3,820 suburTotal assets $ 54,148 $ 41,182 suburLIABILITIES AND SHAREHOLDERS’ EQUITY======Current liabilities: suburAccounts payable $ 2,380 $ 1,193 suburAccrued and other current liabilities 5,472 4,120 suburShort-term debt 1,249 1,250 suburTotal current liabilities 9,101 6,563 suburLong-term operating lease liabilities 1,091 902 suburOther long-term liabilities 2,234 1,913 suburTotal liabilities 20,883 19,081 suburCommit Listing of restricted stock units (2) — (294) — — (295) —294)▬Shares repurchased (28) — – (1) — 3,646) (3,647)▬Cash dividends declared and paid ($0.04 per common share) — � — — —— (100) (100’s)▬Stock-based compensation — — 749 — — 149 — 1 49▬Balances, October 30, 2022 2,468 $ 2 $ 11,565 $ (123) $ 9,905 $ 21,349▬See accompanying Notes to Condensed Consolidated Financial Statements.(In millions, except per share data) Shares Amount Capital Comprehensive Loss Earnings Equity 22 carbohydCash flows from operating activities:sbmNet income $ 17,475 $ 2,954ahimeAdjustments to reconcile net income to net cash provided by operating activities (17,475) (2,954)ahimeStock-based compensation expense 2,555 1,971ahimeDepreciation and amortization 1,121 1,118ahimeLosses on investments in non-affiliates 24 35ahimeDeferred income taxes (2.411) (1,517) suburAcquisition termination cost — 1,353ahimeOther (170) (27) suburChanges in operating assets and liabilitie ...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[2], line 94
#      91 documents = [Document(text=chunk) for chunk in chunks] + [Document(text=table_string)]
#      93 # Initialize VectorStoreIndex
# ---> 94 index = VectorStoreIndex.from_documents(documents)
#      96 # Function to perform QnA
#      97 def ask_question(question):
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/base.py:145, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, service_context, **kwargs)
#     136     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     138 nodes = run_transformations(
#     139     documents,  # type: ignore
#     140     transformations,
#     141     show_progress=show_progress,
#     142     **kwargs,
#     143 )
# --> 145 return cls(
#     146     nodes=nodes,
#     147     storage_context=storage_context,
#     148     callback_manager=callback_manager,
#     149     show_progress=show_progress,
#     150     transformations=transformations,
#     151     service_context=service_context,
#     152     **kwargs,
#     153 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:75, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, service_context, **kwargs)
#      68 self._embed_model = (
#      69     resolve_embed_model(embed_model, callback_manager=callback_manager)
#      70     if embed_model
#      71     else embed_model_from_settings_or_context(Settings, service_context)
#      72 )
#      74 self._insert_batch_size = insert_batch_size
# ---> 75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#      78     service_context=service_context,
#      79     storage_context=storage_context,
#      80     show_progress=show_progress,
#      81     objects=objects,
#      82     callback_manager=callback_manager,
#      83     transformations=transformations,
#      84     **kwargs,
#      85 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/base.py:94, in BaseIndex.__init__(self, nodes, objects, index_struct, storage_context, callback_manager, transformations, show_progress, service_context, **kwargs)
#      92 if index_struct is None:
#      93     nodes = nodes or []
# ---> 94     index_struct = self.build_index_from_nodes(
#      95         nodes + objects, **kwargs  # type: ignore
#      96     )
#      97 self._index_struct = index_struct
#      98 self._storage_context.index_store.add_index_struct(self._index_struct)
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:308, in VectorStoreIndex.build_index_from_nodes(self, nodes, **insert_kwargs)
#     300 if any(
#     301     node.get_content(metadata_mode=MetadataMode.EMBED) == "" for node in nodes
#     302 ):
#     303     raise ValueError(
#     304         "Cannot build index from nodes with no content. "
#     305         "Please ensure all nodes have content."
#     306     )
# --> 308 return self._build_index_from_nodes(nodes, **insert_kwargs)
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:280, in VectorStoreIndex._build_index_from_nodes(self, nodes, **insert_kwargs)
#     278     run_async_tasks(tasks)
#     279 else:
# --> 280     self._add_nodes_to_index(
#     281         index_struct,
#     282         nodes,
#     283         show_progress=self._show_progress,
#     284         **insert_kwargs,
#     285     )
#     286 return index_struct
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:233, in VectorStoreIndex._add_nodes_to_index(self, index_struct, nodes, show_progress, **insert_kwargs)
#     230     return
#     232 for nodes_batch in iter_batch(nodes, self._insert_batch_size):
# --> 233     nodes_batch = self._get_node_with_embedding(nodes_batch, show_progress)
#     234     new_ids = self._vector_store.add(nodes_batch, **insert_kwargs)
#     236     if not self._vector_store.stores_text or self._store_nodes_override:
#     237         # NOTE: if the vector store doesn't store text,
#     238         # we need to add the nodes to the index struct and document store
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/vector_store/base.py:141, in VectorStoreIndex._get_node_with_embedding(self, nodes, show_progress)
#     130 def _get_node_with_embedding(
#     131     self,
#     132     nodes: Sequence[BaseNode],
#     133     show_progress: bool = False,
#     134 ) -> List[BaseNode]:
#     135     """Get tuples of id, node, and embedding.
#     136
#     137     Allows us to store these nodes in a vector store.
#     138     Embeddings are called in batches.
#     139
#     140     """
# --> 141     id_to_embed_map = embed_nodes(
#     142         nodes, self._embed_model, show_progress=show_progress
#     143     )
#     145     results = []
#     146     for node in nodes:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/indices/utils.py:138, in embed_nodes(nodes, embed_model, show_progress)
#     135     else:
#     136         id_to_embed_map[node.node_id] = node.embedding
# --> 138 new_embeddings = embed_model.get_text_embedding_batch(
#     139     texts_to_embed, show_progress=show_progress
#     140 )
#     142 for new_id, text_embedding in zip(ids_to_embed, new_embeddings):
#     143     id_to_embed_map[new_id] = text_embedding
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/core/base/embeddings/base.py:332, in BaseEmbedding.get_text_embedding_batch(self, texts, show_progress, **kwargs)
#     323 dispatcher.event(
#     324     EmbeddingStartEvent(
#     325         model_dict=model_dict,
#     326     )
#     327 )
#     328 with self.callback_manager.event(
#     329     CBEventType.EMBEDDING,
#     330     payload={EventPayload.SERIALIZED: self.to_dict()},
#     331 ) as event:
# --> 332     embeddings = self._get_text_embeddings(cur_batch)
#     333     result_embeddings.extend(embeddings)
#     334     event.on_end(
#     335         payload={
#     336             EventPayload.CHUNKS: cur_batch,
#     337             EventPayload.EMBEDDINGS: embeddings,
#     338         },
#     339     )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/embeddings/openai/base.py:432, in OpenAIEmbedding._get_text_embeddings(self, texts)
#     425 """Get text embeddings.
#     426
#     427 By default, this is a wrapper around _get_text_embedding.
#     428 Can be overridden for batch queries.
#     429
#     430 """
#     431 client = self._get_client()
# --> 432 return get_embeddings(
#     433     client,
#     434     texts,
#     435     engine=self._text_engine,
#     436     **self.additional_kwargs,
#     437 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/local/python/3.10.13/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/llama_index/embeddings/openai/base.py:180, in get_embeddings(client, list_of_text, engine, **kwargs)
#     176 assert len(list_of_text) <= 2048, "The batch size should not be larger than 2048."
#     178 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 180 data = client.embeddings.create(input=list_of_text, model=engine, **kwargs).data
#     181 return [d.embedding for d in data]
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
#     [... skipping similar frames: SyncAPIClient._request at line 1031 (7 times), SyncAPIClient._retry_request at line 1079 (7 times)]
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1031, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1029 if retries > 0 and self._should_retry(err.response):
#    1030     err.response.close()
# -> 1031     return self._retry_request(
#    1032         input_options,
#    1033         cast_to,
#    1034         retries,
#    1035         err.response.headers,
#    1036         stream=stream,
#    1037         stream_cls=stream_cls,
#    1038     )
#    1040 # If the response is streamed then we need to explicitly read the response
#    1041 # to completion before attempting to access the response text.
#    1042 if not err.response.is_closed:
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1079, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1075 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1076 # different thread if necessary.
#    1077 time.sleep(timeout)
# -> 1079 return self._request(
#    1080     options=options,
#    1081     cast_to=cast_to,
#    1082     remaining_retries=remaining,
#    1083     stream=stream,
#    1084     stream_cls=stream_cls,
#    1085 )
#
# File ~/.local/share/virtualenvs/chatbot-ElJdDcMS/lib/python3.10/site-packages/openai/_base_client.py:1046, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1043         err.response.read()
#    1045     log.debug("Re-raising status error")
# -> 1046     raise self._make_status_error_from_response(err.response) from None
#    1048 return self._process_response(
#    1049     cast_to=cast_to,
#    1050     options=options,
#    (...)
#    1053     stream_cls=stream_cls,
#    1054 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
